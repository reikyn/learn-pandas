# %% [markdown]
# # **📝 Practice Questions for Day 05**

# %%
# import libraries
import pandas as pd
import numpy as np 

# Load the data
data = pd.read_csv(r'../data/BMW sales data (2010-2024) (1).csv')
df = pd.DataFrame(data)
df
# Out:
#           Model  Year         Region   Color Fuel_Type Transmission  \
# 0      5 Series  2016           Asia     Red    Petrol       Manual
# 1            i8  2013  North America     Red    Hybrid    Automatic
# 2      5 Series  2022  North America    Blue    Petrol    Automatic
# 3            X3  2024    Middle East    Blue    Petrol    Automatic
# 4      7 Series  2020  South America   Black    Diesel       Manual
# ...         ...   ...            ...     ...       ...          ...
# 49995        i3  2014           Asia     Red    Hybrid       Manual
# 49996        i3  2023    Middle East  Silver  Electric       Manual
# 49997  5 Series  2010    Middle East     Red    Petrol    Automatic
# 49998        i3  2020           Asia   White  Electric    Automatic
# 49999        X1  2020  North America    Blue    Diesel       Manual
#
#        Engine_Size_L  Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# ...

# %% [markdown]
# ***

# %% [markdown]
# ## **🔰Beginner-Level Questions**

# %%
# 1. Sort the dataset by Year in ascending order.
df.sort_values(by='Year')
# Out:
#           Model  Year         Region   Color Fuel_Type Transmission  \
# 39848  7 Series  2010           Asia   Black    Diesel    Automatic
# 37           i8  2010    Middle East    Grey    Petrol    Automatic
# 49979  3 Series  2010         Europe    Grey    Petrol       Manual
# 49978        i3  2010         Europe  Silver  Electric       Manual
# 30           i8  2010  South America   Black    Hybrid    Automatic
# ...         ...   ...            ...     ...       ...          ...
# 3            X3  2024    Middle East    Blue    Petrol    Automatic
# 49968        X3  2024         Europe   White    Petrol       Manual
# 49954        M3  2024         Africa    Blue  Electric    Automatic
# 80           M5  2024  North America   Black    Diesel       Manual
# 74           X1  2024         Europe     Red    Petrol    Automatic
#
#        Engine_Size_L  Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# ...

# %%
# 2. Sort by Sales in descending order to find the top-selling year.
df.sort_values(by='Sales_Volume', ascending=False).head(1)
# Out:
#       Model  Year  Region   Color Fuel_Type Transmission  Engine_Size_L  \
# 27113    X3  2011  Africa  Silver  Electric       Manual            2.0
#
#        Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 27113      123193      79124          9999                 High

# %%
# 3. Find the mean, median, and mode of yearly sales.
# for y in range(2010, 2025):
#     print(f"The yearly sales mean of year {y} is: {df.loc[df['Year'] == y, 'Sales_Volume'].mean()}")
#     print(f"The yearly sales median of year {y} is: {df.loc[df['Year'] == y, 'Sales_Volume'].median()}")
#     print(f"The yearly sales mode of year {y} is: {df.loc[df['Year'] == y, 'Sales_Volume'].mode()[0]}")

# Another Way:
df.groupby('Year')['Sales_Volume'].agg(['mean','median',lambda x: x.mode()[0]])
# Out:
#              mean  median  <lambda_0>
# Year
# 2010  5085.118619  5186.0        5500
# 2011  5112.550641  5149.0         142
# 2012  5027.579532  5052.5         944
# 2013  5071.176488  5111.0         233
# 2014  5062.376119  5082.5        1572
# 2015  5065.576831  5102.0        1652
# 2016  5039.390788  5007.0        1011
# 2017  5051.918237  5107.5        6117
# 2018  5006.794692  5059.5        6025
# 2019  5068.383255  4991.0         300
# 2020  5089.186583  5068.0        1125
# 2021  5007.314947  4978.0        1870
# 2022  5152.658424  5233.5        6215
# 2023  5053.946567  5111.0         839
# 2024  5114.634958  5091.0        4322

# %%
# 4. Use .describe() on the Sales column and interpret the output.
df['Sales_Volume'].describe()
# Out:
# count    50000.000000
# mean      5067.514680
# std       2856.767125
# min        100.000000
# 25%       2588.000000
# 50%       5087.000000
# 75%       7537.250000
# max       9999.000000
# Name: Sales_Volume, dtype: float64

# %% [markdown]
# ***

# %% [markdown]
# ## **🎯Intermediate-Level Questions**

# %%
# 1. Sort the dataset by both Region (alphabetically) and Sales (descending).
df.sort_values(by=['Region', 'Sales_Volume'], ascending=[True, False])
# Out:
#           Model  Year         Region   Color Fuel_Type Transmission  \
# 27113        X3  2011         Africa  Silver  Electric       Manual
# 11924        M3  2017         Africa     Red  Electric       Manual
# 21520        X1  2022         Africa     Red    Hybrid       Manual
# 38972        X6  2010         Africa  Silver  Electric       Manual
# 7974         X3  2015         Africa   White    Diesel    Automatic
# ...         ...   ...            ...     ...       ...          ...
# 46739  5 Series  2024  South America   White  Electric       Manual
# 1822         X1  2012  South America   Black  Electric       Manual
# 22145        X1  2013  South America    Blue    Petrol    Automatic
# 29165  3 Series  2013  South America   White    Diesel       Manual
# 32233        X1  2010  South America    Grey  Electric       Manual
#
#        Engine_Size_L  Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# ...

# %%
# 2. Rank the sales values and add them as a new column Sales_Rank.
df['Sales_Rank'] = df['Sales_Volume'].rank()
df
# Out:
#           Model  Year         Region   Color Fuel_Type Transmission  \
# 0      5 Series  2016           Asia     Red    Petrol       Manual
# 1            i8  2013  North America     Red    Hybrid    Automatic
# 2      5 Series  2022  North America    Blue    Petrol    Automatic
# 3            X3  2024    Middle East    Blue    Petrol    Automatic
# 4      7 Series  2020  South America   Black    Diesel       Manual
# ...         ...   ...            ...     ...       ...          ...
# 49995        i3  2014           Asia     Red    Hybrid       Manual
# 49996        i3  2023    Middle East  Silver  Electric       Manual
# 49997  5 Series  2010    Middle East     Red    Petrol    Automatic
# 49998        i3  2020           Asia   White  Electric    Automatic
# 49999        X1  2020  North America    Blue    Diesel       Manual
#
#        Engine_Size_L  Mileage_KM  Price_USD  Sales_Volume  \
# 0                3.5      151748      98740          8300
# ...

# %%
# 3. Find the standard deviation and variance of sales across all years.
# for y in range(2010, 2025):
#     print(f"The standard deviation of year {y} is: {df.loc[df['Year'] == y, 'Sales_Volume'].std():.2f}")
#     print(f"The standard deviation of year {y} is: {df.loc[df['Year'] == y, 'Sales_Volume'].var():.2f}")

# Another way:
df.groupby('Year')['Sales_Volume'].agg(['std','var'])
# Out:
#               std           var
# Year
# 2010  2856.694496  8.160703e+06
# 2011  2830.544536  8.011982e+06
# 2012  2844.737468  8.092531e+06
# 2013  2843.602613  8.086076e+06
# 2014  2847.011055  8.105472e+06
# 2015  2900.127521  8.410740e+06
# 2016  2835.585389  8.040544e+06
# 2017  2868.915554  8.230676e+06
# 2018  2856.117861  8.157409e+06
# 2019  2859.597569  8.177298e+06
# 2020  2875.412543  8.267997e+06
# 2021  2820.335856  7.954294e+06
# 2022  2863.843010  8.201597e+06
# 2023  2880.973612  8.300009e+06
# 2024  2869.819642  8.235865e+06

# %%
# 4. Use .value_counts() to check how many records belong to each Region.
df['Region'].value_counts()
# Out:
# Region
# Asia             8454
# Middle East      8373
# North America    8335
# Europe           8334
# Africa           8253
# South America    8251
# Name: count, dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# ## **🏆Advanced-Level Questions**

# %%
# 1. Compare the sales trend before and after 2020:
# Compute the average sales from 2010–2019 vs 2020–2024.
# Which period had higher sales?
avg_early = df.loc[df['Year'].between(2010, 2019), 'Sales_Volume'].mean()
avg_recent = df.loc[df['Year'].between(2020, 2024), 'Sales_Volume'].mean()

if avg_recent > avg_early:
    print("2020–2024 has higher sales")
else:
    print("2010–2019 has higher sales")
# Out:
# 2020–2024 has higher sales

# %%
# 2. Group the data by Region and find:
# The year with maximum sales for each region.
# The mean sales for each region.

df_grouped = df.groupby('Region')
df_grouped['Sales_Volume'].mean()
df_grouped['Sales_Volume'].idxmax()   # gives row index of max sales
# Out:
# Region
# Africa           27113
# Asia             43582
# Europe           13521
# Middle East      25672
# North America    39518
# South America    47953
# Name: Sales_Volume, dtype: int64

# %%
# 3. Sort all years by sales, then filter the top 3 years with the highest sales per region.
df.sort_values(by=['Region','Sales_Volume'], ascending=[True,False]).groupby('Region').head(3)
# Out:
#           Model  Year         Region   Color Fuel_Type Transmission  \
# 27113        X3  2011         Africa  Silver  Electric       Manual
# 11924        M3  2017         Africa     Red  Electric       Manual
# 21520        X1  2022         Africa     Red    Hybrid       Manual
# 43582        X5  2013           Asia    Blue    Diesel       Manual
# 38187        i8  2013           Asia    Blue    Hybrid       Manual
# 31010        X5  2014           Asia    Blue    Petrol    Automatic
# 13521  7 Series  2024         Europe  Silver    Diesel    Automatic
# 38529        M3  2022         Europe     Red    Petrol       Manual
# 29259        i8  2012         Europe    Blue    Diesel       Manual
# 25672        i8  2010    Middle East     Red    Hybrid    Automatic
# 47616        X1  2012    Middle East    Blue    Diesel       Manual
# 5516         i8  2023    Middle East     Red    Diesel    Automatic
# 39518  3 Series  2017  North America   Black  Electric    Automatic
# ...

# %%
# 4. Create a custom function sales_summary(df) that:
# Returns min, max, mean, median, std, and IQR of the sales column.
# Apply it to the BMW dataset.
def sales_summary(df):
    q25 = df['Sales_Volume'].quantile(0.25)
    q75 = df['Sales_Volume'].quantile(0.75)
    iqr = q75 - q25
    
    stats = df['Sales_Volume'].agg(['min','max','mean','median','std'])
    stats['IQR'] = iqr
    
    return stats

sales_summary(df)
# Out:
# min        100.000000
# max       9999.000000
# mean      5067.514680
# median    5087.000000
# std       2856.767125
# IQR       4949.250000
# Name: Sales_Volume, dtype: float64

# %% [markdown]
# ***
