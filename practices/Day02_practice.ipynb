# %% [markdown]
# # **📝 Practice Questions for Day 02**

# %%
import pandas as pd

data = pd.read_csv(r'..\datasets\Students Social Media Addiction.csv')
df = pd.DataFrame(data)

# %% [markdown]
# ***

# %% [markdown]
# ## **🔰Beginner-Level Questions**

# %%
# Select the column Age as a Series and as a DataFrame.
df['Age']  # Series
df[['Age']]  # DataFrame
# Out:
#      Age
# 0     19
# 1     22
# 2     20
# 3     18
# 4     21
# ..   ...
# 700   20
# 701   23
# 702   21
# 703   24
# 704   19
#
# [705 rows x 1 columns]

# %%
# Select the first 5 rows using .iloc.
df.iloc[:5]
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
# ...

# %%
# Select the last row using .loc and .iloc.
df.loc[df.index[-1]]
df.loc[len(df)-1]
df.iloc[-1]
# Out:
# Student_ID                                705
# Age                                        19
# Gender                                 Female
# Academic_Level                  Undergraduate
# Country                                Poland
# Avg_Daily_Usage_Hours                     6.2
# Most_Used_Platform                   Facebook
# Affects_Academic_Performance              Yes
# Sleep_Hours_Per_Night                     6.3
# Mental_Health_Score                         5
# Relationship_Status                    Single
# Conflicts_Over_Social_Media                 4
# Addicted_Score                              8
# Name: 704, dtype: object

# %%
# Select columns Name and City for the first 10 rows.
df.loc[:9, ['Student_ID', 'Country']]
# Out:
#    Student_ID      Country
# 0           1   Bangladesh
# 1           2        India
# 2           3          USA
# 3           4           UK
# 4           5       Canada
# 5           6    Australia
# 6           7      Germany
# 7           8       Brazil
# 8           9        Japan
# 9          10  South Korea

# %% [markdown]
# ***

# %% [markdown]
# ## **🎯Intermediate-Level Questions**

# %%
# Get all rows where Age is greater than 21.
df.loc[df['Age'] > 21]
# Out:
#      Student_ID  Age  Gender Academic_Level      Country  \
# 1             2   22    Male       Graduate        India
# 6             7   23    Male       Graduate      Germany
# 12           13   22    Male       Graduate        Italy
# 16           17   24    Male       Graduate       Sweden
# 21           22   23  Female       Graduate  Switzerland
# ..          ...  ...     ...            ...          ...
# 695         696   23    Male       Graduate          USA
# 697         698   24    Male       Graduate       France
# 699         700   22    Male       Graduate           UK
# 701         702   23    Male       Graduate       Russia
# 703         704   24    Male       Graduate        Japan
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 1                      2.1            Twitter                           No
# 6                      1.5           LinkedIn                           No
# ...

# %%
# Get all students whose Country is either USA or UK.
df[df['Country'].isin(['USA', 'UK'])]
df[(df['Country'] == 'USA') | (df['Country'] == 'UK')]
# Out:
#      Student_ID  Age  Gender Academic_Level Country  Avg_Daily_Usage_Hours  \
# 2             3   20  Female  Undergraduate     USA                    6.0
# 3             4   18    Male    High School      UK                    3.0
# 220         221   19  Female  Undergraduate     USA                    6.5
# 221         222   21    Male       Graduate      UK                    5.8
# 228         229   19  Female  Undergraduate     USA                    7.0
# ..          ...  ...     ...            ...     ...                    ...
# 665         666   23    Male       Graduate      UK                    6.3
# 678         679   21  Female  Undergraduate     USA                    5.3
# 682         683   20  Female  Undergraduate      UK                    6.1
# 695         696   23    Male       Graduate     USA                    5.5
# 699         700   22    Male       Graduate      UK                    6.2
#
# ...

# %%
# Select rows where Age is between 18 and 21.
df.query('18 <= Age <= 21')
# df[df['Age'].between(18, 21)]
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 2             3   20  Female  Undergraduate         USA
# 3             4   18    Male    High School          UK
# 4             5   21    Male       Graduate      Canada
# 5             6   19  Female  Undergraduate   Australia
# ..          ...  ...     ...            ...         ...
# 696         697   21  Female  Undergraduate      Mexico
# 698         699   19  Female  Undergraduate      Canada
# 700         701   20  Female  Undergraduate       Italy
# 702         703   21  Female  Undergraduate       China
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 2                      6.0             TikTok                          Yes
# ...

# %%
# Get only the Acedemic Score and Age of students older than 20.
df.loc[df['Age'] > 20, ['Affects_Academic_Performance', 'Age']]
# Out:
#     Affects_Academic_Performance  Age
# 1                             No   22
# 4                            Yes   21
# 6                             No   23
# 9                             No   21
# 12                            No   22
# ..                           ...  ...
# 697                           No   24
# 699                          Yes   22
# 701                          Yes   23
# 702                          Yes   21
# 703                           No   24
#
# [363 rows x 2 columns]

# %% [markdown]
# ***

# %% [markdown]
# ## **🏆Advanced-Level Questions**

# %%
# Using multiple conditions: get students where Age > 20 and Country == "South Korea".
df.query('Age > 20 and Country == "South Korea"')
# Out:
#    Student_ID  Age  Gender Academic_Level      Country  Avg_Daily_Usage_Hours  \
# 9          10   21  Female       Graduate  South Korea                    3.3
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 9          Instagram                           No                    7.0
#
#    Mental_Health_Score Relationship_Status  Conflicts_Over_Social_Media  \
# 9                    7     In Relationship                            1
#
#    Addicted_Score
# 9               4

# %%
# Select all rows except those from Canada.
# df[~df['Country'].eq('Canada')]
df[~df['Country'].isin(['Canada'])]
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 1             2   22    Male       Graduate       India
# 2             3   20  Female  Undergraduate         USA
# 3             4   18    Male    High School          UK
# 5             6   19  Female  Undergraduate   Australia
# ..          ...  ...     ...            ...         ...
# 700         701   20  Female  Undergraduate       Italy
# 701         702   23    Male       Graduate      Russia
# 702         703   21  Female  Undergraduate       China
# 703         704   24    Male       Graduate       Japan
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 1                      2.1            Twitter                           No
# ...

# %%
# Use .query() to get students with Age < 22 or Country == "India".
df.query('Age < 22 or Country == "India"')
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 1             2   22    Male       Graduate       India
# 2             3   20  Female  Undergraduate         USA
# 3             4   18    Male    High School          UK
# 4             5   21    Male       Graduate      Canada
# ..          ...  ...     ...            ...         ...
# 696         697   21  Female  Undergraduate      Mexico
# 698         699   19  Female  Undergraduate      Canada
# 700         701   20  Female  Undergraduate       Italy
# 702         703   21  Female  Undergraduate       China
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 1                      2.1            Twitter                           No
# ...

# %%
# From the dataset, create a new filtered DataFrame of students who are from "South Korea", Average daily usage is in between 3 to 5 and
# have Age between 19–23, selecting only Student ID, relationship status, and Gender
filtered = df.query('Country == "South Korea" and 3 <= Avg_Daily_Usage_Hours <= 5 and 19 <= Age <= 23')
filtered[['Student_ID', 'Gender', 'Relationship_Status']]
# Out:
#      Student_ID  Gender Relationship_Status
# 9            10  Female     In Relationship
# 234         235  Female              Single
# 250         251  Female              Single
# 258         259  Female     In Relationship
# 266         267  Female              Single
# 274         275  Female     In Relationship
# 282         283  Female              Single
# 290         291  Female     In Relationship
# 298         299  Female              Single
# 306         307  Female     In Relationship
# 314         315  Female              Single
