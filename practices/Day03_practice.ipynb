# %% [markdown]
# # 📝 Practice Questions for Day 03
#
# (Organized using Bloom’s Taxonomy → from Beginner → Intermediate → Advanced/Pro).

# %% [markdown]
# #### Prepare the Data

# %%
# import necessary libraries
import pandas as pd
import numpy as np

# Load the Netflix data
data = pd.read_csv(r'../data/Netflix Dataset.csv')
df = pd.DataFrame(data)
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ## 🌱 Beginner (Remember & Understand)

# %%
# 1. Load the Netflix dataset and check:
# Total missing values in each column.
# Which column has the most missing values?
print(df.isna().sum())
print(f"{df.isna().sum().idxmax()} has the most missing values: {df.isna().sum()['Director']}")
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64
# Director has the most missing values: 2388

# %%
# 2. Select only the Country column and count how many missing values it has.
print(f"Country column has: {df['Country'].isna().sum()} missing values")
# Out:
# Country column has: 507 missing values

# %%
# 3. Use .dropna() to remove all rows with any missing values. How many rows remain?
df_dropped = df.dropna()
print(f"Remained rows after dropping: {(df_dropped.shape)[0]}")
# Out:
# Remained rows after dropping: 4811

# %%
# 4. View columns with more than 500 null values
thresh_value = 500
null_count = df.isna().sum()
columns_to_view = null_count[null_count > thresh_value].index
df[columns_to_view]
# Out:
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7784        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                NaN                                            Nasty C
# 7787                NaN                         Adriano Zumbo, Rachel Khoo
# 7788           Sam Dunn                                                NaN
#
#                                                 Country
# ...

# %% [markdown]
# ## 🌿 Intermediate (Apply & Analyze)

# %%
# 5. From the Netflix dataset:
# Filter only rows where Type == 'Movie'.
# Now fill missing values in the Director column with "Unknown".
df_filtered = df[df['Category'] == 'Movie']
dff = df_filtered.fillna({'Director': 'Unknown'})
dff.loc[dff['Director'] == 'Unknown']
# Out:
#      Show_Id Category                                              Title  \
# 19       s20    Movie                                                '89
# 52       s53    Movie                               100 Days Of Solitude
# 55       s56    Movie                100 Things to do Before High School
# 67       s68    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 81       s82    Movie                                 2015 Dream Concert
# ...      ...      ...                                                ...
# 7497   s7496    Movie                      We Are All For The Fatherland
# 7694   s7693    Movie  Ya no estoy aquí: Una conversación entre Guill...
# 7704   s7703    Movie                                   Yeh Hai Bakrapur
# 7718   s7717    Movie                               Yoko and His Friends
# 7786   s7785    Movie                                  Zulu Man in Japan
#
#      Director                                               Cast  \
# ...

# %%
# 6. Drop all columns where more than 50% values are missing.
thresh_value = 0.1 * len(df)
# Director column has most missing values 2388
df_cleaned = df.dropna(axis=1, thresh=6000) # columns that has less than 600 non-null values will be dropped
df_cleaned
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
# 7. Detect duplicate rows and remove them. How many were removed?
df_duplicates = df.duplicated(keep=False)
df_duplicates
df[df_duplicates]

df.drop_duplicates()
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# 8. Replace all missing values in the Rating column with the mode (most common rating).
most_common_rating = df['Rating'].mode()[0]
most_common_rating
df.isna().sum()['Rating'] # rating column has 7 missing values
df.fillna({'Rating': most_common_rating}) # replacing null values with most common rating
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ## 🌳 Advanced / Pro (Evaluate & Create)

# %%
# 9. Combine skills:
# Select only shows released after 2015,
shows_after2015 = df[(df['Category'] == 'TV Show') & (df['Release_Date'] > 'December 31, 2015')]
# Filter those available in “India”,
avail_india = shows_after2015[shows_after2015['Country'] == 'India']
# Then drop all rows with missing Duration.
print(f"Missing Durations: {avail_india.Duration.isna().sum()}")
avail_india = avail_india.dropna(subset='Duration')
# Finally, fill missing Director with "Not Provided".
avail_india.Director.isna().sum()
new_df = avail_india.fillna({'Director': 'Not Provided'})
new_df
# Out:
# Missing Durations: 0
#      Show_Id Category                                    Title  \
# 132     s133  TV Show                                7 (Seven)
# 364     s365  TV Show                             Akbar Birbal
# 534     s535  TV Show              Anjaan: Special Crimes Unit
# 686     s687  TV Show              Bad Boy Billionaires: India
# 750     s751  TV Show                            Bard of Blood
# 856     s857  TV Show                                   Betaal
# 880     s881  TV Show                       Bhaag Beanie Bhaag
# 1316   s1317  TV Show                             Chhota Bheem
# 1412   s1413  TV Show                          Classic Legends
# 1463   s1464  TV Show                          College Romance
# 1533   s1534  TV Show            Cricket Fever: Mumbai Indians
# 1622   s1623  TV Show                     Darr Sabko Lagta Hai
# 1691   s1692  TV Show                              Delhi Crime
# ...

# %%
# 10. Create a function clean_column(df, col_name) that:
# Drops rows where col_name is missing, Removes duplicates, Returns the cleaned column as a Series.
def clean_column(df, col_name):
    # return df[col_name].dropna().drop_duplicates()
    return df.dropna(subset=col_name).drop_duplicates(subset=col_name)[col_name]
clean_column(df, 'Rating')
# Out:
# 0          TV-MA
# 2              R
# 3          PG-13
# 8          TV-14
# 19         TV-PG
# 25            NR
# 31          TV-G
# 55          TV-Y
# 108        TV-Y7
# 145           PG
# 155            G
# 996        NC-17
# 1662    TV-Y7-FV
# 2484          UR
# Name: Rating, dtype: object

# %%
# 11. Design your own cleaning pipeline:
# Apply it on the Netflix dataset and explain why each step improves data quality.
# Step 1: Drop columns with >30% missing.
thresh_value = 0.7 * len(df)
df2 = df.dropna(axis=1, thresh=thresh_value).copy()
df2
# Step 2: Fill categorical columns with mode, numeric with median.
fill_values = {col: df2[col].mode()[0] for col in df2.columns if df2[col].isna().sum()}
df2.fillna(value=fill_values, inplace=True)
# Step 3: Remove duplicates.
df2.drop_duplicates(inplace=True)
# Step 4: Reset the index.
df2.reset_index(drop=True, inplace=True)

df2

# step1 Ensures that we have only sufficient data, avoiding noise from mostly empty columns
# step2 Efficiently handle the missing data in a systemetic way, reducing information loss while keeping consistency.
# step3 Removes duplicate rows so analysis isn't biased by repeaded data.
# step4 Resets index so rows are properly numbered after dropping and deduplicating
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
# Conditional Filling:
# For rows where Type == "TV Show" and Director is missing, fill it with "TV Unknown".
# For rows where Type == "Movie" and Director is missing, fill it with "Movie Unknown".
tv = df.copy()
tv.loc[(df['Category'] == 'TV Show') & (df['Director'].isna()), 'Director'] = 'TV Unknown'
tv.loc[(df['Category'] == 'Movie') & (df['Director'].isna()), 'Director'] = 'Movie Unknown'
tv
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0            TV Unknown  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# Custom Imputation Function
# Write a function that:
# Accepts a DataFrame and a list of column names,
# For each numeric column → fill missing with median,
# For each categorical column → fill missing with mode,
# Returns the cleaned DataFrame.
# Test it on the Netflix dataset.
def clean_columns(df, cols):
    dfc = df.copy()
    for col in cols:
        if dfc[col].dtype == object:
            # dfc[col] = dfc[col].fillna(dfc[col].mode()[0])
            dfc.fillna({col: dfc[col].mode()[0]}, inplace=True)
        else:
            # dfc[col] = dfc[col].fillna(dfc[col].median())
            dfc.fillna({col: dfc[col].median()}, inplace=True)
    return dfc
new_dff = clean_columns(df, ['Show_Id', 'Title','Director', 'Rating'])
new_dff
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                     Director  \
# 0     Raúl Campos, Jan Suter
# 1          Jorge Michel Grau
# 2               Gilbert Chan
# 3                Shane Acker
# 4             Robert Luketic
# ...
